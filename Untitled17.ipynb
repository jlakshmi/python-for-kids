# %% [markdown]
# <a href="https://colab.research.google.com/github/jlakshmi/python-for-kids/blob/master/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import statsmodels.api as sm

# %%
from sklearn import datasets

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv("data.csv")
print(df1)
# Out:
#                      State  Confirmed  Active  Recovered  Deceased
# 0      Andaman and Nicobar         33       0         33         0
# 1           Andhra Pradesh       2205     965       1192        48
# 2        Arunachal Pradesh          1       0          1         0
# 3                    Assam         87      46         39         2
# 4                    Bihar        994     576        411         7
# 5               Chandigarh        191     151         37         3
# 6             Chhattisgarh         60       4         56         0
# 7   Dadra and Nagar Haveli          1       1          0         0
# 8            Daman and Diu          0       0          0         0
# 9                    Delhi       8470    5310       3045       115
# 10                     Goa         14       7          7         0
# 11                 Gujarat       9591    5252       3753       586
# 12                 Haryana        818     368        439        11
# 13        Himachal Pradesh         74      33         39         2
# 14       Jammu and Kashmir        983     487        485        11
# 15               Jharkhand        197     107         87         3
# 16               Karnataka        987     492        460        35
# 17                  Kerala        560      65        491         4
# 18                  Ladakh         43      21         22         0
# 19             Lakshadweep          0       0          0         0
# 20          Madhya Pradesh       4426    2018       2171       237
# 21              Maharastra      27524   20446       6059      1019
# 22                 Manipur          3       1          2         0
# 23               Meghalaya         13       1         11         1
# 24                 Mizoram          1       0          1         0
# 25                Nagaland          0       0          0         0
# 26                  Odisha        611     450        158         3
# 27              Puducherry         13       3          9         1
# 28                  Punjab       1935    1680        223        32
# 29               Rajasthan       4534    1829       2580       125
# 30                  Sikkim          0       0          0         0
# 31              Tamil Nadu       9674    7368       2240        66
# 32               Telangana       1414     430        950        34
# 33                 Tripura        156     127         29         0
# 34           Uttar Pradesh       3902    1742       2072        88
# 35             Uttarakhand         78      27         50         1
# 36             West Bengal       2377    1394        768       215

# %%
target = pd.DataFrame(df1.Deceased, columns=["Deceased"])

# %%
x = df1["Active"]
y = target["Deceased"]

# %%
model = sm.OLS(y, x).fit()
predictions = model.predict(x) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               Deceased   R-squared (uncentered):                   0.829
# Model:                            OLS   Adj. R-squared (uncentered):              0.824
# Method:                 Least Squares   F-statistic:                              174.5
# Date:                Sat, 16 May 2020   Prob (F-statistic):                    2.26e-15
# Time:                        14:39:38   Log-Likelihood:                         -216.50
# No. Observations:                  37   AIC:                                      435.0
# Df Residuals:                      36   BIC:                                      436.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Active         0.0482      0.004     13.209      0.000       0.041       0.056
# ==============================================================================
# Omnibus:                       19.055   Durbin-Watson:                   1.943
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              100.578
# Skew:                           0.551   Prob(JB):                     1.44e-22
# Kurtosis:                      11.002   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
target = pd.DataFrame(df1.Deceased, columns=["Deceased"])
X = df1[["Confirmed","Active","Recovered","Deceased"]]
y = target["Deceased"]

# %%
from sklearn import linear_model
lm = linear_model.LinearRegression()
model = lm.fit(X,y)

# %%
predictions = lm.predict(X)

# %%
print(predictions)
# Out:
# [-1.66977543e-13  4.80000000e+01 -1.70419234e-13  2.00000000e+00
#   7.00000000e+00  3.00000000e+00 -1.64313008e-13 -1.70446990e-13
#  -1.70530257e-13  1.15000000e+02 -1.68975944e-13  5.86000000e+02
#   1.10000000e+01  2.00000000e+00  1.10000000e+01  3.00000000e+00
#   3.50000000e+01  4.00000000e+00 -1.66089364e-13 -1.70530257e-13
#   2.37000000e+02  1.01900000e+03 -1.70252701e-13  1.00000000e+00
#  -1.70419234e-13 -1.70530257e-13  3.00000000e+00  1.00000000e+00
#   3.20000000e+01  1.25000000e+02 -1.70530257e-13  6.60000000e+01
#   3.40000000e+01 -1.56319402e-13  8.80000000e+01  1.00000000e+00
#   2.15000000e+02]

# %%
from pandas.plotting import andrews_curves
andrews_curves(df1,"State",ax=None)

# %%
import pandas as pd
import numpy as np
import datetime
import requests
import warnings

import matplotlib.pyplot as plt
import matplotlib
import matplotlib.dates as mdates
import seaborn as sns
import plotly.offline as py
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import OrdinalEncoder
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from statsmodels.tsa.arima_model import ARIMA
from fbprophet import Prophet
from fbprophet.plot import plot_plotly, add_changepoints_to_plot

from IPython.display import Image
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
labels = list(df1.State)
decease = list(df1.Deceased)

# %%
print(labels)
# Out:
# ['Andaman and Nicobar', 'Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh', 'Dadra and Nagar Haveli', 'Daman and Diu', 'Delhi', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh', 'Lakshadweep', 'Madhya Pradesh', 'Maharastra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal']

# %%
explode = []

for i in labels:
    explode.append(0.05)
    
plt.figure(figsize= (15,10))
plt.pie(decease, labels=labels, autopct='%1.1f%%', startangle=9, explode =explode)
centre_circle = plt.Circle((0,0),0.70,fc='white')

fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.tight_layout()

# %%
df1['Active'] = df1['Confirmed'] - (df1['Deceased']+df1['Recovered'])
df1["Deceased Rate (per 100)"] = np.round(100*df1["Deceased"]/df1["Confirmed"],2)
df1["Recovered Rate (per 100)"] = np.round(100*df1["Recovered"]/df1["Confirmed"],2)
df1.sort_values('Confirmed', ascending= False).fillna(0).style.background_gradient(cmap='Blues',subset=["Confirmed"])\
                        .background_gradient(cmap='Blues',subset=["Deceased"])\
                        .background_gradient(cmap='Blues',subset=["Recovered"])\
                        .background_gradient(cmap='Blues',subset=["Active"])\
                        .background_gradient(cmap='Blues',subset=["Deceased Rate (per 100)"])\
                        .background_gradient(cmap='Blues',subset=["Recovered Rate (per 100)"])
# Out:
# <style  type="text/css" >
#     #T_129ea994_9783_11ea_b9e3_0242ac1c0002row0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row0_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row0_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row0_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row0_col5 {
#             background-color:  #91c3de;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row0_col6 {
#             background-color:  #ccdff1;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row1_col1 {
#             background-color:  #a6cee4;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row1_col2 {
#             background-color:  #a3cce3;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row1_col3 {
#             background-color:  #a0cbe2;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row1_col4 {
#             background-color:  #eaf3fb;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row1_col5 {
#             background-color:  #e8f1fa;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row1_col6 {
#             background-color:  #caddf0;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row2_col1 {
#             background-color:  #a6cee4;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row2_col2 {
#             background-color:  #c4daee;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row2_col3 {
#             background-color:  #4493c7;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row2_col4 {
#             background-color:  #529dcc;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row2_col5 {
#             background-color:  #3585bf;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row2_col6 {
#             background-color:  #97c6df;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row3_col1 {
#             background-color:  #b4d3e9;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row3_col2 {
#             background-color:  #c3daee;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row3_col3 {
#             background-color:  #6aaed6;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row3_col4 {
#             background-color:  #e1edf8;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row3_col5 {
#             background-color:  #d9e8f5;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row3_col6 {
#             background-color:  #a3cce3;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row4_col1 {
#             background-color:  #d6e6f4;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row4_col2 {
#             background-color:  #e6f0f9;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row4_col3 {
#             background-color:  #89bedc;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row4_col4 {
#             background-color:  #dfebf7;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row4_col5 {
#             background-color:  #b4d3e9;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row4_col6 {
#             background-color:  #549fcd;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row5_col1 {
#             background-color:  #d7e6f5;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row5_col2 {
#             background-color:  #e3eef9;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row5_col3 {
#             background-color:  #a4cce3;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row5_col4 {
#             background-color:  #caddf0;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row5_col5 {
#             background-color:  #4d99ca;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row5_col6 {
#             background-color:  #6fb0d7;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row6_col1 {
#             background-color:  #dbe9f6;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row6_col2 {
#             background-color:  #e7f0fa;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row6_col3 {
#             background-color:  #a9cfe5;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row6_col4 {
#             background-color:  #e6f0f9;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row6_col5 {
#             background-color:  #c7dbef;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row6_col6 {
#             background-color:  #61a7d2;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row7_col1 {
#             background-color:  #e6f0f9;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row7_col2 {
#             background-color:  #eaf2fb;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row7_col3 {
#             background-color:  #deebf7;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row7_col4 {
#             background-color:  #cde0f1;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row7_col5 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row7_col6 {
#             background-color:  #afd1e7;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row8_col1 {
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row8_col2 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row8_col3 {
#             background-color:  #d0e2f2;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row8_col4 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row8_col5 {
#             background-color:  #c8dcf0;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row8_col6 {
#             background-color:  #5da5d1;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row9_col1 {
#             background-color:  #eaf2fb;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row9_col2 {
#             background-color:  #e7f0fa;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row9_col3 {
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row9_col4 {
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row9_col5 {
#             background-color:  #d3e4f3;
#             color:  #000000;
#         }    #T_129ea994_9783_11ea_b9e3_0242ac1c0002row9_col6 {
#             background-color:  #e0ecf8;
#             color:  #000000;

# %%
df2= pd.read_csv("hotspot.csv")

# %%
df2.Red
# Out:
# 0      1.0
# 1      5.0
# 2      0.0
# 3      0.0
# 4      5.0
# 5      1.0
# 6      1.0
# 7      0.0
# 8      0.0
# 9     11.0
# 10     0.0
# 11     9.0
# 12     2.0
# 13     0.0
# 14     4.0
# 15     1.0
# 16     3.0
# 17     2.0
# 18     0.0
# 19     0.0
# 20     9.0
# 21    14.0
# 22     0.0
# 23     0.0
# 24     0.0
# 25     0.0
# 26     3.0
# 27     0.0
# 28     3.0
# 29     8.0
# 30     0.0
# 31    12.0
# 32     6.0
# 33     0.0
# 34    19.0
# 35     1.0
# 36    10.0
# 37     NaN
# Name: Red, dtype: float64

# %%
df2.State
# Out:
# 0        Andaman and Nicobar
# 1             Andhra Pradesh
# 2          Arunachal Pradesh
# 3                      Assam
# 4                      Bihar
# 5                 Chandigarh
# 6               Chhattisgarh
# 7     Dadra and Nagar Haveli
# 8              Daman and Diu
# 9                      Delhi
# 10                       Goa
# 11                   Gujarat
# 12                   Haryana
# 13          Himachal Pradesh
# 14         Jammu and Kashmir
# 15                 Jharkhand
# 16                 Karnataka
# 17                    Kerala
# 18                    Ladakh
# 19               Lakshadweep
# 20            Madhya Pradesh
# 21                Maharastra
# 22                   Manipur
# 23                 Meghalaya
# 24                   Mizoram
# 25                  Nagaland
# 26                    Odisha
# 27                Puducherry
# 28                    Punjab
# 29                 Rajasthan
# 30                    Sikkim
# 31                Tamil Nadu
# 32                 Telangana
# 33                   Tripura
# 34             Uttar Pradesh
# 35               Uttarakhand
# 36               West Bengal
# 37                       NaN
# Name: State, dtype: object

# %%
df2.dropna
# Out:
# <bound method DataFrame.dropna of                      State   Red  Orange  Green
# 0      Andaman and Nicobar   1.0     0.0    2.0
# 1           Andhra Pradesh   5.0     7.0    1.0
# 2        Arunachal Pradesh   0.0     0.0   25.0
# 3                    Assam   0.0     3.0   30.0
# 4                    Bihar   5.0    20.0   13.0
# 5               Chandigarh   1.0     0.0    0.0
# 6             Chhattisgarh   1.0     1.0   25.0
# 7   Dadra and Nagar Haveli   0.0     0.0    1.0
# 8            Daman and Diu   0.0     0.0    2.0
# 9                    Delhi  11.0     0.0    0.0
# 10                     Goa   0.0     0.0    2.0
# 11                 Gujarat   9.0    19.0    5.0
# 12                 Haryana   2.0    18.0    2.0
# 13        Himachal Pradesh   0.0     6.0    6.0
# 14       Jammu and Kashmir   4.0    12.0    4.0
# 15               Jharkhand   1.0     9.0   14.0
# 16               Karnataka   3.0    13.0   14.0
# 17                  Kerala   2.0    10.0    2.0
# 18                  Ladakh   0.0     2.0    0.0
# 19             Lakshadweep   0.0     0.0    1.0
# 20          Madhya Pradesh   9.0    19.0   24.0
# 21              Maharastra  14.0    16.0    6.0
# 22                 Manipur   0.0     0.0   16.0
# 23               Meghalaya   0.0     1.0   10.0
# 24                 Mizoram   0.0     0.0   11.0
# 25                Nagaland   0.0     0.0   11.0
# 26                  Odisha   3.0     6.0   21.0
# 27              Puducherry   0.0     1.0    3.0
# 28                  Punjab   3.0    15.0    4.0
# 29               Rajasthan   8.0    19.0    6.0
# 30                  Sikkim   0.0     0.0    4.0
# 31              Tamil Nadu  12.0    24.0    1.0
# 32               Telangana   6.0    18.0    9.0
# 33                 Tripura   0.0     2.0    6.0
# 34           Uttar Pradesh  19.0    36.0   20.0
# 35             Uttarakhand   1.0     2.0   10.0
# 36             West Bengal  10.0     5.0    8.0
# 37                     NaN   NaN     NaN    NaN>

# %%
df3=df2.drop(37)

# %%
df3
# Out:
#                      State   Red  Orange  Green
# 0      Andaman and Nicobar   1.0     0.0    2.0
# 1           Andhra Pradesh   5.0     7.0    1.0
# 2        Arunachal Pradesh   0.0     0.0   25.0
# 3                    Assam   0.0     3.0   30.0
# 4                    Bihar   5.0    20.0   13.0
# 5               Chandigarh   1.0     0.0    0.0
# 6             Chhattisgarh   1.0     1.0   25.0
# 7   Dadra and Nagar Haveli   0.0     0.0    1.0
# 8            Daman and Diu   0.0     0.0    2.0
# 9                    Delhi  11.0     0.0    0.0
# 10                     Goa   0.0     0.0    2.0
# 11                 Gujarat   9.0    19.0    5.0
# 12                 Haryana   2.0    18.0    2.0
# 13        Himachal Pradesh   0.0     6.0    6.0
# 14       Jammu and Kashmir   4.0    12.0    4.0
# 15               Jharkhand   1.0     9.0   14.0
# 16               Karnataka   3.0    13.0   14.0
# 17                  Kerala   2.0    10.0    2.0
# 18                  Ladakh   0.0     2.0    0.0
# 19             Lakshadweep   0.0     0.0    1.0
# 20          Madhya Pradesh   9.0    19.0   24.0
# 21              Maharastra  14.0    16.0    6.0
# 22                 Manipur   0.0     0.0   16.0
# 23               Meghalaya   0.0     1.0   10.0
# 24                 Mizoram   0.0     0.0   11.0
# 25                Nagaland   0.0     0.0   11.0
# 26                  Odisha   3.0     6.0   21.0
# 27              Puducherry   0.0     1.0    3.0
# 28                  Punjab   3.0    15.0    4.0
# 29               Rajasthan   8.0    19.0    6.0
# 30                  Sikkim   0.0     0.0    4.0
# 31              Tamil Nadu  12.0    24.0    1.0
# 32               Telangana   6.0    18.0    9.0
# 33                 Tripura   0.0     2.0    6.0
# 34           Uttar Pradesh  19.0    36.0   20.0
# 35             Uttarakhand   1.0     2.0   10.0
# 36             West Bengal  10.0     5.0    8.0

# %%
plt.scatter(df3.State,df3.Red)

# %%
plt.figure(figsize= (10,10))
plt.hlines(y=df3['State'], xmin=0, xmax=40, color='grey', alpha=0.4);
plt.scatter(df3['Red'], df3['State'], color='skyblue', label='Red Zone');
plt.scatter(df3['Orange'], df3['State'], color='Green', label='Orange Zone');
plt.scatter(df3['Green'], df3['State'], color='Red', label='Green Zone');

# %%
df1.columns
# Out:
# Index(['State', 'Confirmed', 'Active', 'Recovered', 'Deceased',
#        'Deceased Rate (per 100)', 'Recovered Rate (per 100)'],
#       dtype='object')

# %%
df4=pd.read_csv("hotty.csv")

# %%
df4.columns
# Out:
# Index(['State', 'Red', 'Orange', 'Green', 'Total'], dtype='object')

# %%
hotty = pd.pivot_table(df4, values=['Red','Orange','Green','Total'], index='State', aggfunc='max')
state_names = list(hotty.index)
hotty['State'] = state_names
plt.figure(figsize=(25,10))
sns.set_color_codes("pastel")

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Total',y='State',data = df4,label="Total",color='#9370db')
sns.barplot(x='Red',y='State',data = df4,label="Total",color='Blue')
sns.barplot(x='Orange',y='State',data = df4,label="Total",color='Red')
sns.barplot(x='Green',y='State',data = df4,label="Total",color='Green')
